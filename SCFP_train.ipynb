# %% [markdown]
# ### CNN Model with SCFP for the target SR-p35 (based on paper): Training

# %%
import time, gc, os
import datetime
import numpy as np
import cupy as cp
from rdkit import Chem
from SCFP_functions.feature import *
import SCFP_functions.SCFPfunctions as Mf
import SCFP_functions.SCFPmodel as Mm
from SCFP_functions.constants import lensize
from SCFP_functions.constants import scfp_model_args as args
import chainer
from chainer import training
from chainer import datasets
from chainer.training import extensions

# %%
#-------------------------------
# GPU check
xp = np
if args["gpu"] >= 0:
    print('GPU mode')
    xp = cp
# Out:
# GPU mode

# %% [markdown]
# ### Model: Training

# %%
print('Making Training  Dataset...')
file="data/tox21_SR-p53/tox21_data_train.smiles"
print('Loading smiles: ', file)
smi = Chem.SmilesMolSupplier(file,delimiter=' ',titleLine=False)
mols = [mol for mol in smi if mol is not None]

F_list, T_list = [],[]
for mol in mols:
    if len(Chem.MolToSmiles(mol, kekuleSmiles=True, isomericSmiles=True)) > args["atomsize"]: print("SMILES is too long. This mol will be ignored.")
    else:
        F_list.append(mol_to_feature(mol,-1,args["atomsize"]))
        T_list.append(mol.GetProp('_Name'))
Mf.random_list(F_list)
Mf.random_list(T_list)
data_t = xp.asarray(T_list, dtype=cp.int32).reshape(-1,args["n_out"])
data_f = xp.asarray(F_list, dtype=cp.float32).reshape(-1,args["n_out"],args["atomsize"],lensize)
print(data_t.shape, data_f.shape)
train_dataset = datasets.TupleDataset(data_f, data_t)

# %%
print('Making Test Dataset...')
file="data/tox21_SR-p53/tox21_data_test.smiles"
print('Loading smiles: ', file)
smi = Chem.SmilesMolSupplier(file,delimiter='\t',titleLine=False)
mols = [mol for mol in smi if mol is not None]
F_list, T_list = [],[]
for mol in mols:
    if len(Chem.MolToSmiles(mol, kekuleSmiles=True, isomericSmiles=True)) > args["atomsize"]: print("SMILES is too long. This mol will be ignored.")
    else:
        F_list.append(mol_to_feature(mol,-1,args["atomsize"]))
        T_list.append(mol.GetProp('_Name'))            
Mf.random_list(F_list)
Mf.random_list(T_list)
data_t = xp.asarray(T_list, dtype=cp.int32).reshape(-1,1)
data_f = xp.asarray(F_list, dtype=cp.float32).reshape(-1,1,args["atomsize"],lensize)
print(data_t.shape, data_f.shape)
test_dataset = datasets.TupleDataset(data_f, data_t)

# %%
# reset memory
del mol, mols, data_f, data_t, F_list, T_list
gc.collect()
# Out:
# 0

# %%
# Set up a neural network to train
model = Mm.CNN(args["atomsize"], lensize, args["k1"], args["s1"], args["f1"], args["k2"], args["s2"], args["k3"], args["s3"], args["f3"],args["k4"], args["s4"],args["n_hid"],args["n_out"])

# %%
if args["gpu"] >= 0:
    chainer.cuda.get_device_from_id(args["gpu"]).use()
    model.to_gpu()
    print("Copied the model to the GPU!")
# Out:
# Copied the model to the GPU!

# %%
optimizer = chainer.optimizers.Adam()
optimizer.setup(model)

# %%
output_dir = "model_output"
os.makedirs(output_dir)

train_iter = chainer.iterators.SerialIterator(train_dataset, batch_size= args["batchsize"], shuffle=True)
test_iter = chainer.iterators.SerialIterator(test_dataset, batch_size= args["batchsize"], repeat=False, shuffle=True)
updater = training.StandardUpdater(train_iter, optimizer, device=args["gpu"])
trainer = training.Trainer(updater, (args["epoch"], 'epoch'), out=output_dir)

# Evaluate the model with the test dataset for each epoch
trainer.extend(extensions.Evaluator(test_iter, model, device=args["gpu"]))
# Take a snapshot for each specified epoch
trainer.extend(extensions.snapshot_object(model, 'model_snapshot_{.updater.epoch}'), trigger=(args["frequency"],'epoch'))
# Write a log of evaluation statistics for each epoch    
trainer.extend(extensions.LogReport(trigger=(1, 'epoch'), log_name='log_epoch'))
trainer.extend(extensions.LogReport(trigger=(10, 'iteration'), log_name='log_iteration'))
# Print selected entries of the log to stdout
trainer.extend(extensions.PrintReport( ['epoch', 'elapsed_time','main/loss', 'validation/main/loss','main/accuracy','validation/main/accuracy']))
# Print a progress bar to stdout
trainer.extend(extensions.ProgressBar())

# %%
# Run the training
START = time.time()

trainer.run()

END = time.time()
print('Training done. Total time was {}'.format(str(datetime.timedelta(seconds=END-START))))
# Out:
# d:\PythonVirtualEnvironments\SCFP-PGrLGv28\lib\site-packages\chainer\functions\connection\convolution_2d.py:295: PerformanceWarning: The best algo of conv fwd might not be selected due to lack of workspace size (8388608)
#   cuda.cudnn.convolution_forward(
# epoch       elapsed_time  main/loss   validation/main/loss  main/accuracy  validation/main/accuracy
#      total [..................................................]  0.09%
# this epoch [######################............................] 44.61%
#        100 iter, 0 epoch / 500 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  0.18%
# this epoch [############################################......] 89.21%
#        200 iter, 0 epoch / 500 epochs
#     125.31 iters/sec. Estimated time to finish: 0:14:52.914635.
# 1           4.54267       0.262389    0.199369              0.928611       0.9375
#      total [..................................................]  0.27%
# this epoch [################..................................] 33.82%
#        300 iter, 1 epoch / 500 epochs
#     117.44 iters/sec. Estimated time to finish: 0:15:51.924353.
#      total [..................................................]  0.36%
# this epoch [#######################################...........] 78.42%
#        400 iter, 1 epoch / 500 epochs
#     120.39 iters/sec. Estimated time to finish: 0:15:27.802522.
# 2           6.38204       0.200068    0.225549              0.938756       0.930729
#      total [..................................................]  0.45%
# this epoch [###########.......................................] 23.03%
#        500 iter, 2 epoch / 500 epochs
#     119.15 iters/sec. Estimated time to finish: 0:15:36.558959.
#      total [..................................................]  0.54%
# this epoch [#################################.................] 67.63%
#        600 iter, 2 epoch / 500 epochs
#     120.95 iters/sec. Estimated time to finish: 0:15:21.830764.
# 3           8.22154       0.190929    0.217116              0.938895       0.932813
#      total [..................................................]  0.62%
# this epoch [######............................................] 12.24%
#        700 iter, 3 epoch / 500 epochs
#     119.74 iters/sec. Estimated time to finish: 0:15:30.323808.
#      total [..................................................]  0.71%
# this epoch [############################......................] 56.84%
#        800 iter, 3 epoch / 500 epochs
#     120.73 iters/sec. Estimated time to finish: 0:15:21.830134.
# 4           10.0709       0.175123    0.208778              0.942662       0.928125
#      total [..................................................]  0.80%
# this epoch [..................................................]  1.45%
#        900 iter, 4 epoch / 500 epochs
#     119.86 iters/sec. Estimated time to finish: 0:15:27.705011.
#      total [..................................................]  0.89%
# this epoch [#######################...........................] 46.06%
#       1000 iter, 4 epoch / 500 epochs
#     120.67 iters/sec. Estimated time to finish: 0:15:20.659642.
#      total [..................................................]  0.98%
# this epoch [#############################################.....] 90.66%
#       1100 iter, 4 epoch / 500 epochs
#     121.29 iters/sec. Estimated time to finish: 0:15:15.088969.
# 5           11.9304       0.165905    0.219129              0.943638       0.939062
#      total [..................................................]  1.07%
# this epoch [#################.................................] 35.27%
#       1200 iter, 5 epoch / 500 epochs
#     120.54 iters/sec. Estimated time to finish: 0:15:19.965306.
#      total [..................................................]  1.16%
# this epoch [#######################################...........] 79.87%
#       1300 iter, 5 epoch / 500 epochs
#      120.9 iters/sec. Estimated time to finish: 0:15:16.403589.
# 6           13.8087       0.157308    0.228181              0.94375        0.9375
#      total [..................................................]  1.25%
# this epoch [############......................................] 24.48%
#       1400 iter, 6 epoch / 500 epochs
#     120.15 iters/sec. Estimated time to finish: 0:15:21.270750.
#      total [..................................................]  1.34%
# this epoch [##################################................] 69.08%
#       1500 iter, 6 epoch / 500 epochs
#     120.58 iters/sec. Estimated time to finish: 0:15:17.178579.
# 7           15.6806       0.141816    0.236454              0.949219       0.905729
#      total [..................................................]  1.43%
# this epoch [######............................................] 13.69%
#       1600 iter, 7 epoch / 500 epochs
#     119.92 iters/sec. Estimated time to finish: 0:15:21.408003.
#      total [..................................................]  1.52%
# this epoch [#############################.....................] 58.29%
#       1700 iter, 7 epoch / 500 epochs
#     120.22 iters/sec. Estimated time to finish: 0:15:18.235438.
# 8           17.5807       0.133716    0.248056              0.951869       0.907812
#      total [..................................................]  1.61%
# this epoch [#.................................................]  2.90%
#       1800 iter, 8 epoch / 500 epochs
#     119.65 iters/sec. Estimated time to finish: 0:15:21.766656.
#      total [..................................................]  1.70%
# this epoch [#######################...........................] 47.50%
#       1900 iter, 8 epoch / 500 epochs
#     119.81 iters/sec. Estimated time to finish: 0:15:19.720429.
#      total [..................................................]  1.78%
# this epoch [##############################################....] 92.11%
#       2000 iter, 8 epoch / 500 epochs
#     119.91 iters/sec. Estimated time to finish: 0:15:18.153538.
# 9           19.5031       0.12452     0.217559              0.95452        0.920313
#      total [..................................................]  1.87%
# this epoch [##################................................] 36.72%
#       2100 iter, 9 epoch / 500 epochs
#     119.28 iters/sec. Estimated time to finish: 0:15:22.160596.
#      total [..................................................]  1.96%
# this epoch [########################################..........] 81.32%
#       2200 iter, 9 epoch / 500 epochs
#      119.4 iters/sec. Estimated time to finish: 0:15:20.360598.
# 10          21.4487       0.108317    0.26147               0.959821       0.90625
#      total [#.................................................]  2.05%
# this epoch [############......................................] 25.93%
#       2300 iter, 10 epoch / 500 epochs
#     117.44 iters/sec. Estimated time to finish: 0:15:34.863251.
#      total [#.................................................]  2.14%
# this epoch [###################################...............] 70.53%
#       2400 iter, 10 epoch / 500 epochs
#     117.57 iters/sec. Estimated time to finish: 0:15:32.988193.
# 11          23.6155       0.0993444   0.271099              0.964306       0.928125
#      total [#.................................................]  2.23%
# this epoch [#######...........................................] 15.14%
#       2500 iter, 11 epoch / 500 epochs
#     116.94 iters/sec. Estimated time to finish: 0:15:37.165329.
#      total [#.................................................]  2.32%
# this epoch [#############################.....................] 59.74%
#       2600 iter, 11 epoch / 500 epochs
#     117.23 iters/sec. Estimated time to finish: 0:15:34.027750.
# 12          25.5825       0.0879212   0.279808              0.970424       0.929688
#      total [#.................................................]  2.41%
# this epoch [##................................................]  4.35%
#       2700 iter, 12 epoch / 500 epochs
#     116.95 iters/sec. Estimated time to finish: 0:15:35.360792.
#      total [#.................................................]  2.50%
# this epoch [########################..........................] 48.95%
#       2800 iter, 12 epoch / 500 epochs
#     117.18 iters/sec. Estimated time to finish: 0:15:32.682530.
#      total [#.................................................]  2.59%
# this epoch [##############################################....] 93.56%
#       2900 iter, 12 epoch / 500 epochs
#     117.26 iters/sec. Estimated time to finish: 0:15:31.215935.
# 13          27.5193       0.078481    0.283942              0.969587       0.918229
#      total [#.................................................]  2.68%
# this epoch [###################...............................] 38.17%
#       3000 iter, 13 epoch / 500 epochs
#     116.93 iters/sec. Estimated time to finish: 0:15:33.003539.
#      total [#.................................................]  2.77%
# this epoch [#########################################.........] 82.77%
#       3100 iter, 13 epoch / 500 epochs
#     116.98 iters/sec. Estimated time to finish: 0:15:31.740485.
# 14          29.6521       0.0792912   0.494347              0.970285       0.930729
#      total [#.................................................]  2.85%
# this epoch [#############.....................................] 27.38%
#       3200 iter, 14 epoch / 500 epochs
#     115.74 iters/sec. Estimated time to finish: 0:15:40.813028.
#      total [#.................................................]  2.94%
# this epoch [###################################...............] 71.98%
#       3300 iter, 14 epoch / 500 epochs
#     115.84 iters/sec. Estimated time to finish: 0:15:39.168177.
# 15          31.6593       0.0641354   0.291956              0.976842       0.929688
#      total [#.................................................]  3.03%
# this epoch [########..........................................] 16.59%
#       3400 iter, 15 epoch / 500 epochs
#     115.51 iters/sec. Estimated time to finish: 0:15:41.030302.
#      total [#.................................................]  3.12%
# this epoch [##############################....................] 61.19%
#       3500 iter, 15 epoch / 500 epochs
#     115.66 iters/sec. Estimated time to finish: 0:15:38.926470.
# 16          33.6361       0.0606136   0.295142              0.978376       0.914062
#      total [#.................................................]  3.21%
# this epoch [##................................................]  5.80%
#       3600 iter, 16 epoch / 500 epochs
#     115.41 iters/sec. Estimated time to finish: 0:15:40.057426.
#      total [#.................................................]  3.30%
# this epoch [#########################.........................] 50.40%
#       3700 iter, 16 epoch / 500 epochs
#     115.54 iters/sec. Estimated time to finish: 0:15:38.123204.
#      total [#.................................................]  3.39%
# this epoch [###############################################...] 95.01%
#       3800 iter, 16 epoch / 500 epochs
#     115.65 iters/sec. Estimated time to finish: 0:15:36.408843.
# 17          35.6114       0.0481789   0.409543              0.983611       0.934375
#      total [#.................................................]  3.48%
# this epoch [###################...............................] 39.62%
#       3900 iter, 17 epoch / 500 epochs
#     115.44 iters/sec. Estimated time to finish: 0:15:37.232718.
#      total [#.................................................]  3.57%
# this epoch [##########################################........] 84.22%
#       4000 iter, 17 epoch / 500 epochs
#     115.57 iters/sec. Estimated time to finish: 0:15:35.278450.
# 18          37.5589       0.0552685   0.369636              0.979771       0.919792
#      total [#.................................................]  3.66%
# this epoch [##############....................................] 28.83%
#       4100 iter, 18 epoch / 500 epochs
#     115.36 iters/sec. Estimated time to finish: 0:15:36.161440.
#      total [#.................................................]  3.75%
# this epoch [####################################..............] 73.43%
#       4200 iter, 18 epoch / 500 epochs
#     115.43 iters/sec. Estimated time to finish: 0:15:34.688088.
# 19          39.5323       0.0407591   0.352443              0.986607       0.911979
#      total [#.................................................]  3.84%
# this epoch [#########.........................................] 18.04%
#       4300 iter, 19 epoch / 500 epochs
#      115.2 iters/sec. Estimated time to finish: 0:15:35.685231.
#      total [#.................................................]  3.93%
# this epoch [###############################...................] 62.64%
#       4400 iter, 19 epoch / 500 epochs
#     112.99 iters/sec. Estimated time to finish: 0:15:53.101417.
# 20          42.2933       0.0402658   0.400301              0.986049       0.929688
#      total [##................................................]  4.01%
# this epoch [###...............................................]  7.25%
#       4500 iter, 20 epoch / 500 epochs
#     112.79 iters/sec. Estimated time to finish: 0:15:53.904594.
#      total [##................................................]  4.10%
# this epoch [#########################.........................] 51.85%
#       4600 iter, 20 epoch / 500 epochs
#     112.83 iters/sec. Estimated time to finish: 0:15:52.741365.
#      total [##................................................]  4.19%
# this epoch [################################################..] 96.46%
#       4700 iter, 20 epoch / 500 epochs
#     112.83 iters/sec. Estimated time to finish: 0:15:51.848311.
# 21          44.353        0.0436453   0.364909              0.983259       0.921875
#      total [##................................................]  4.28%
# this epoch [####################..............................] 41.06%
#       4800 iter, 21 epoch / 500 epochs
#     112.58 iters/sec. Estimated time to finish: 0:15:53.005391.
#      total [##................................................]  4.37%
# this epoch [##########################################........] 85.67%
#       4900 iter, 21 epoch / 500 epochs
#     112.66 iters/sec. Estimated time to finish: 0:15:51.509489.
# 22          46.4138       0.0429041   0.491132              0.984167       0.918229
#      total [##................................................]  4.46%
# this epoch [###############...................................] 30.28%
#       5000 iter, 22 epoch / 500 epochs
#     112.45 iters/sec. Estimated time to finish: 0:15:52.399737.
#      total [##................................................]  4.55%
# this epoch [#####################################.............] 74.88%
#       5100 iter, 22 epoch / 500 epochs
#     112.53 iters/sec. Estimated time to finish: 0:15:50.774866.
# 23          48.4266       0.0360778   0.358875              0.986886       0.935938
#      total [##................................................]  4.64%
# this epoch [#########.........................................] 19.49%
#       5200 iter, 23 epoch / 500 epochs
#     112.38 iters/sec. Estimated time to finish: 0:15:51.173266.
#      total [##................................................]  4.73%
# this epoch [################################..................] 64.09%
#       5300 iter, 23 epoch / 500 epochs
#     112.47 iters/sec. Estimated time to finish: 0:15:49.549059.
# 24          50.4659       0.0334859   0.457419              0.988421       0.921354
#      total [##................................................]  4.82%
# this epoch [####..............................................]  8.70%
#       5400 iter, 24 epoch / 500 epochs
#     112.26 iters/sec. Estimated time to finish: 0:15:50.388467.
#      total [##................................................]  4.91%
# this epoch [##########################........................] 53.30%
#       5500 iter, 24 epoch / 500 epochs
#     112.34 iters/sec. Estimated time to finish: 0:15:48.831666.
#      total [##................................................]  5.00%
# this epoch [################################################..] 97.91%
#       5600 iter, 24 epoch / 500 epochs
#      112.4 iters/sec. Estimated time to finish: 0:15:47.454767.
# 25          52.4873       0.0288233   0.430791              0.989258       0.909375
#      total [##................................................]  5.09%
# this epoch [#####################.............................] 42.51%
#       5700 iter, 25 epoch / 500 epochs
#     112.22 iters/sec. Estimated time to finish: 0:15:48.072072.
#      total [##................................................]  5.17%
# this epoch [###########################################.......] 87.12%
#       5800 iter, 25 epoch / 500 epochs
#     112.23 iters/sec. Estimated time to finish: 0:15:47.084434.
# 26          54.5454       0.031362    0.422205              0.98856        0.910417
#      total [##................................................]  5.26%
# this epoch [###############...................................] 31.73%
#       5900 iter, 26 epoch / 500 epochs
#     112.05 iters/sec. Estimated time to finish: 0:15:47.713087.
#      total [##................................................]  5.35%
# this epoch [######################################............] 76.33%
#       6000 iter, 26 epoch / 500 epochs
#      112.1 iters/sec. Estimated time to finish: 0:15:46.435697.
# 27          56.6192       0.0287057   0.575421              0.989167       0.915104
#      total [##................................................]  5.44%
# this epoch [##########........................................] 20.94%
#       6100 iter, 27 epoch / 500 epochs
#     111.94 iters/sec. Estimated time to finish: 0:15:46.920796.
#      total [##................................................]  5.53%
# this epoch [################################..................] 65.54%
#       6200 iter, 27 epoch / 500 epochs
#     111.97 iters/sec. Estimated time to finish: 0:15:45.691094.
# 28          58.6967       0.0272155   0.557995              0.990932       0.913021
#      total [##................................................]  5.62%
# this epoch [#####.............................................] 10.15%
#       6300 iter, 28 epoch / 500 epochs
#     111.75 iters/sec. Estimated time to finish: 0:15:46.725245.
#      total [##................................................]  5.71%
# this epoch [###########################.......................] 54.75%
#       6400 iter, 28 epoch / 500 epochs
#     111.73 iters/sec. Estimated time to finish: 0:15:45.983406.
#      total [##................................................]  5.80%
# this epoch [#################################################.] 99.36%
#       6500 iter, 28 epoch / 500 epochs
#     111.73 iters/sec. Estimated time to finish: 0:15:45.038505.
# 29          60.814        0.0300723   0.458065              0.989955       0.915104
#      total [##................................................]  5.89%
# this epoch [#####################.............................] 43.96%
#       6600 iter, 29 epoch / 500 epochs
#     111.53 iters/sec. Estimated time to finish: 0:15:45.896745.
#      total [##................................................]  5.98%
# this epoch [############################################......] 88.57%
#       6700 iter, 29 epoch / 500 epochs
#     111.51 iters/sec. Estimated time to finish: 0:15:45.181580.
# 30          62.9433       0.0270332   0.533241              0.991211       0.928125
#      total [###...............................................]  6.07%
# this epoch [################..................................] 33.18%
#       6800 iter, 30 epoch / 500 epochs
#     111.25 iters/sec. Estimated time to finish: 0:15:46.449110.
#      total [###...............................................]  6.16%
# this epoch [######################################............] 77.78%
#       6900 iter, 30 epoch / 500 epochs
#     111.15 iters/sec. Estimated time to finish: 0:15:46.449539.
# 31          65.1256       0.0232992   0.489836              0.992467       0.932813
#      total [###...............................................]  6.24%
# this epoch [###########.......................................] 22.39%
#       7000 iter, 31 epoch / 500 epochs
#     111.01 iters/sec. Estimated time to finish: 0:15:46.726907.
#      total [###...............................................]  6.33%
# this epoch [#################################.................] 66.99%
#       7100 iter, 31 epoch / 500 epochs
#     111.03 iters/sec. Estimated time to finish: 0:15:45.633430.
# 32          67.2388       0.0233845   0.594471              0.991629       0.911458
#      total [###...............................................]  6.42%
# this epoch [#####.............................................] 11.60%
#       7200 iter, 32 epoch / 500 epochs
#     110.83 iters/sec. Estimated time to finish: 0:15:46.436865.
#      total [###...............................................]  6.51%
# this epoch [############################......................] 56.20%
#       7300 iter, 32 epoch / 500 epochs
#     110.82 iters/sec. Estimated time to finish: 0:15:45.617777.
# 33          69.3726       0.0194157   0.479653              0.994028       0.928125
#      total [###...............................................]  6.60%
# this epoch [..................................................]  0.81%
#       7400 iter, 33 epoch / 500 epochs
#     110.64 iters/sec. Estimated time to finish: 0:15:46.216126.
#      total [###...............................................]  6.69%
# this epoch [######################............................] 45.41%
#       7500 iter, 33 epoch / 500 epochs
#     110.62 iters/sec. Estimated time to finish: 0:15:45.555506.
#      total [###...............................................]  6.78%
# this epoch [#############################################.....] 90.02%
#       7600 iter, 33 epoch / 500 epochs
#     110.63 iters/sec. Estimated time to finish: 0:15:44.553573.
# 34          71.5136       0.0246995   0.556773              0.990792       0.921354
#      total [###...............................................]  6.87%
# this epoch [#################.................................] 34.63%
#       7700 iter, 34 epoch / 500 epochs
#     110.48 iters/sec. Estimated time to finish: 0:15:44.873075.
#      total [###...............................................]  6.96%
# this epoch [#######################################...........] 79.23%
#       7800 iter, 34 epoch / 500 epochs
#      110.5 iters/sec. Estimated time to finish: 0:15:43.858185.
# 35          73.6182       0.0311489   0.552878              0.987584       0.915104
#      total [###...............................................]  7.05%
# this epoch [###########.......................................] 23.84%
#       7900 iter, 35 epoch / 500 epochs
#     109.02 iters/sec. Estimated time to finish: 0:15:55.709994.
#      total [###...............................................]  7.14%
# this epoch [##################################................] 68.44%
#       8000 iter, 35 epoch / 500 epochs
#     109.06 iters/sec. Estimated time to finish: 0:15:54.437857.
# 36          76.5926       0.0337643   0.469667              0.987444       0.907812
#      total [###...............................................]  7.23%
# this epoch [######............................................] 13.05%
#       8100 iter, 36 epoch / 500 epochs
#     108.94 iters/sec. Estimated time to finish: 0:15:54.574780.
#      total [###...............................................]  7.32%
# this epoch [############################......................] 57.65%
#       8200 iter, 36 epoch / 500 epochs
#     108.94 iters/sec. Estimated time to finish: 0:15:53.658434.
# 37          78.7241       0.0205167   0.507804              0.992048       0.894792
#      total [###...............................................]  7.40%
# this epoch [#.................................................]  2.26%
#       8300 iter, 37 epoch / 500 epochs
#     108.82 iters/sec. Estimated time to finish: 0:15:53.830141.
#      total [###...............................................]  7.49%
# this epoch [#######################...........................] 46.86%
#       8400 iter, 37 epoch / 500 epochs
#     108.84 iters/sec. Estimated time to finish: 0:15:52.736707.
#      total [###...............................................]  7.58%
# this epoch [#############################################.....] 91.47%
#       8500 iter, 37 epoch / 500 epochs
#     108.86 iters/sec. Estimated time to finish: 0:15:51.654737.
# 38          80.8442       0.0153775   0.521257              0.995833       0.93125
#      total [###...............................................]  7.67%
# this epoch [##################................................] 36.07%
#       8600 iter, 38 epoch / 500 epochs
#     108.75 iters/sec. Estimated time to finish: 0:15:51.702415.
#      total [###...............................................]  7.76%
# this epoch [########################################..........] 80.68%
#       8700 iter, 38 epoch / 500 epochs
#     108.75 iters/sec. Estimated time to finish: 0:15:50.703888.
# 39          82.9843       0.0144133   0.560018              0.995257       0.929688
#      total [###...............................................]  7.85%
# this epoch [############......................................] 25.29%
#       8800 iter, 39 epoch / 500 epochs
#     108.65 iters/sec. Estimated time to finish: 0:15:50.728317.
#      total [###...............................................]  7.94%
# this epoch [##################################................] 69.89%
#       8900 iter, 39 epoch / 500 epochs
#     108.63 iters/sec. Estimated time to finish: 0:15:49.955551.
# 40          85.1448       0.0163224   0.54911               0.99442        0.908854
#      total [####..............................................]  8.03%
# this epoch [#######...........................................] 14.50%
#       9000 iter, 40 epoch / 500 epochs
#     107.84 iters/sec. Estimated time to finish: 0:15:55.976460.
#      total [####..............................................]  8.12%
# this epoch [#############################.....................] 59.10%
#       9100 iter, 40 epoch / 500 epochs
#     107.86 iters/sec. Estimated time to finish: 0:15:54.897097.
# 41          87.8001       0.0183525   0.536643              0.993304       0.916667
#      total [####..............................................]  8.21%
# this epoch [#.................................................]  3.71%
#       9200 iter, 41 epoch / 500 epochs
#     107.75 iters/sec. Estimated time to finish: 0:15:54.929991.
#      total [####..............................................]  8.30%
# this epoch [########################..........................] 48.31%
#       9300 iter, 41 epoch / 500 epochs
#     107.75 iters/sec. Estimated time to finish: 0:15:53.989904.
#      total [####..............................................]  8.39%
# this epoch [##############################################....] 92.92%
#       9400 iter, 41 epoch / 500 epochs
#     107.75 iters/sec. Estimated time to finish: 0:15:53.061176.
# 42          89.9692       0.0221134   0.516802              0.992188       0.920313
#      total [####..............................................]  8.48%
# this epoch [##################................................] 37.52%
#       9500 iter, 42 epoch / 500 epochs
#     107.62 iters/sec. Estimated time to finish: 0:15:53.278419.
#      total [####..............................................]  8.56%
# this epoch [#########################################.........] 82.13%
#       9600 iter, 42 epoch / 500 epochs
#     107.61 iters/sec. Estimated time to finish: 0:15:52.422850.
# 43          92.1829       0.0232578   0.457323              0.991806       0.914062
#      total [####..............................................]  8.65%
# this epoch [#############.....................................] 26.74%
#       9700 iter, 43 epoch / 500 epochs
#     107.49 iters/sec. Estimated time to finish: 0:15:52.600515.
#      total [####..............................................]  8.74%
# this epoch [###################################...............] 71.34%
#       9800 iter, 43 epoch / 500 epochs
#     107.48 iters/sec. Estimated time to finish: 0:15:51.750748.
# 44          94.3638       0.0208906   0.494024              0.992746       0.926562
#      total [####..............................................]  8.83%
# this epoch [#######...........................................] 15.95%
#       9900 iter, 44 epoch / 500 epochs
#     107.36 iters/sec. Estimated time to finish: 0:15:51.848437.
#      total [####..............................................]  8.92%
# this epoch [##############################....................] 60.55%
#      10000 iter, 44 epoch / 500 epochs
#     107.36 iters/sec. Estimated time to finish: 0:15:50.943664.
# 45          96.5461       0.0223283   0.610482              0.992467       0.919792
#      total [####..............................................]  9.01%
# this epoch [##................................................]  5.16%
#      10100 iter, 45 epoch / 500 epochs
#     107.05 iters/sec. Estimated time to finish: 0:15:52.752953.
#      total [####..............................................]  9.10%
# this epoch [########################..........................] 49.76%
#      10200 iter, 45 epoch / 500 epochs
#     107.01 iters/sec. Estimated time to finish: 0:15:52.189166.
#      total [####..............................................]  9.19%
# this epoch [###############################################...] 94.37%
#      10300 iter, 45 epoch / 500 epochs
#     106.83 iters/sec. Estimated time to finish: 0:15:52.817587.
# 46          98.7955       0.0132226   0.473136              0.996233       0.904688
#      total [####..............................................]  9.28%
# this epoch [###################...............................] 38.97%
#      10400 iter, 46 epoch / 500 epochs
#     106.63 iters/sec. Estimated time to finish: 0:15:53.709703.
#      total [####..............................................]  9.37%
# this epoch [#########################################.........] 83.58%
#      10500 iter, 46 epoch / 500 epochs
#     106.44 iters/sec. Estimated time to finish: 0:15:54.496159.
# 47          101.002       0.016428    0.608816              0.995396       0.911979
#      total [####..............................................]  9.46%
# this epoch [##############....................................] 28.19%
#      10600 iter, 47 epoch / 500 epochs
#     106.25 iters/sec. Estimated time to finish: 0:15:55.268699.
#      total [####..............................................]  9.55%
# this epoch [####################################..............] 72.79%
#      10700 iter, 47 epoch / 500 epochs
#     106.06 iters/sec. Estimated time to finish: 0:15:55.976440.
# 48          103.236       0.0163327   0.574868              0.993443       0.907292
#      total [####..............................................]  9.63%
# this epoch [########..........................................] 17.40%
#      10800 iter, 48 epoch / 500 epochs
#     105.85 iters/sec. Estimated time to finish: 0:15:56.962156.
#      total [####..............................................]  9.72%
# this epoch [###############################...................] 62.00%
#      10900 iter, 48 epoch / 500 epochs
#     105.66 iters/sec. Estimated time to finish: 0:15:57.704034.
# 49          105.474       0.0167965   0.630804              0.993611       0.93125
#      total [####..............................................]  9.81%
# this epoch [###...............................................]  6.61%
#      11000 iter, 49 epoch / 500 epochs
#     105.37 iters/sec. Estimated time to finish: 0:15:59.402624.
#      total [####..............................................]  9.90%
# this epoch [#########################.........................] 51.21%
#      11100 iter, 49 epoch / 500 epochs
#     105.29 iters/sec. Estimated time to finish: 0:15:59.228911.
#      total [####..............................................]  9.99%
# this epoch [###############################################...] 95.82%
#      11200 iter, 49 epoch / 500 epochs
#     105.11 iters/sec. Estimated time to finish: 0:15:59.868961.
# 50          107.701       0.0157936   0.540848              0.99428        0.884896
#      total [#####.............................................] 10.08%
# this epoch [####################..............................] 40.42%
#      11300 iter, 50 epoch / 500 epochs
#     104.77 iters/sec. Estimated time to finish: 0:16:02.012322.
#      total [#####.............................................] 10.17%
# this epoch [##########################################........] 85.03%
#      11400 iter, 50 epoch / 500 epochs
#     104.59 iters/sec. Estimated time to finish: 0:16:02.750281.
# 51          110.105       0.0229232   0.534514              0.990932       0.925
#      total [#####.............................................] 10.26%
# this epoch [##############....................................] 29.63%
#      11500 iter, 51 epoch / 500 epochs
#     104.42 iters/sec. Estimated time to finish: 0:16:03.379655.
#      total [#####.............................................] 10.35%
# this epoch [#####################################.............] 74.24%
#      11600 iter, 51 epoch / 500 epochs
#     104.25 iters/sec. Estimated time to finish: 0:16:03.974711.
# 52          112.326       0.0166921   0.58915               0.994001       0.926562
#      total [#####.............................................] 10.44%
# this epoch [#########.........................................] 18.85%
#      11700 iter, 52 epoch / 500 epochs
#     104.08 iters/sec. Estimated time to finish: 0:16:04.536369.
#      total [#####.............................................] 10.53%
# this epoch [###############################...................] 63.45%
#      11800 iter, 52 epoch / 500 epochs
#     103.92 iters/sec. Estimated time to finish: 0:16:05.105677.
# 53          114.592       0.0142788   0.653928              0.994001       0.916667
#      total [#####.............................................] 10.62%
# this epoch [####..............................................]  8.06%
#      11900 iter, 53 epoch / 500 epochs
#     103.67 iters/sec. Estimated time to finish: 0:16:06.508166.
#      total [#####.............................................] 10.71%
# this epoch [##########################........................] 52.66%
#      12000 iter, 53 epoch / 500 epochs
#     103.62 iters/sec. Estimated time to finish: 0:16:05.938662.
#      total [#####.............................................] 10.79%
# this epoch [################################################..] 97.27%
#      12100 iter, 53 epoch / 500 epochs
#     103.46 iters/sec. Estimated time to finish: 0:16:06.498851.
# 54          116.846       0.0122667   0.519551              0.996667       0.907292
#      total [#####.............................................] 10.88%
# this epoch [####################..............................] 41.87%
#      12200 iter, 54 epoch / 500 epochs
#     103.55 iters/sec. Estimated time to finish: 0:16:04.726713.
#      total [#####.............................................] 10.97%
# this epoch [###########################################.......] 86.48%
#      12300 iter, 54 epoch / 500 epochs
#      103.4 iters/sec. Estimated time to finish: 0:16:05.153005.
# 55          119.583       0.012591    0.626577              0.995954       0.922917
#      total [#####.............................................] 11.06%
# this epoch [###############...................................] 31.08%
#      12400 iter, 55 epoch / 500 epochs
#     102.76 iters/sec. Estimated time to finish: 0:16:10.199752.
#      total [#####.............................................] 11.15%
# this epoch [#####################################.............] 75.69%
#      12500 iter, 55 epoch / 500 epochs
#     102.58 iters/sec. Estimated time to finish: 0:16:10.906530.
# 56          121.875       0.0134721   0.545044              0.995257       0.921875
#      total [#####.............................................] 11.24%
# this epoch [##########........................................] 20.30%
#      12600 iter, 56 epoch / 500 epochs
#     102.41 iters/sec. Estimated time to finish: 0:16:11.509897.
#      total [#####.............................................] 11.33%
# this epoch [################################..................] 64.90%
#      12700 iter, 56 epoch / 500 epochs
#     102.24 iters/sec. Estimated time to finish: 0:16:12.190925.
# 57          124.159       0.021571    0.568691              0.992467       0.911979
#      total [#####.............................................] 11.42%
# this epoch [####..............................................]  9.51%
#      12800 iter, 57 epoch / 500 epochs
#     101.97 iters/sec. Estimated time to finish: 0:16:13.753853.
#      total [#####.............................................] 11.51%
# this epoch [###########################.......................] 54.11%
#      12900 iter, 57 epoch / 500 epochs
#     101.91 iters/sec. Estimated time to finish: 0:16:13.344257.
#      total [#####.............................................] 11.60%
# this epoch [#################################################.] 98.72%
#      13000 iter, 57 epoch / 500 epochs
#     101.77 iters/sec. Estimated time to finish: 0:16:13.734242.
# 58          126.473       0.0212785   0.556377              0.992048       0.896875
#      total [#####.............................................] 11.69%
# this epoch [#####################.............................] 43.32%
#      13100 iter, 58 epoch / 500 epochs
#     101.83 iters/sec. Estimated time to finish: 0:16:12.186939.
#      total [#####.............................................] 11.78%
# this epoch [###########################################.......] 87.93%
#      13200 iter, 58 epoch / 500 epochs
#     101.67 iters/sec. Estimated time to finish: 0:16:12.723314.
# 59          128.777       0.0154145   0.623492              0.994028       0.908854
#      total [#####.............................................] 11.87%
# this epoch [################..................................] 32.53%
#      13300 iter, 59 epoch / 500 epochs
#     101.51 iters/sec. Estimated time to finish: 0:16:13.226598.
#      total [#####.............................................] 11.95%
# this epoch [######################################............] 77.14%
#      13400 iter, 59 epoch / 500 epochs
#     101.15 iters/sec. Estimated time to finish: 0:16:15.708943.
# 60          131.303       0.010548    0.561992              0.996094       0.928125
#      total [######............................................] 12.04%
# this epoch [##########........................................] 21.75%
#      13500 iter, 60 epoch / 500 epochs
#     100.99 iters/sec. Estimated time to finish: 0:16:16.313312.
#      total [######............................................] 12.13%
# this epoch [#################################.................] 66.35%
#      13600 iter, 60 epoch / 500 epochs
#     100.82 iters/sec. Estimated time to finish: 0:16:16.932659.
# 61          133.623       0.00839562  0.705866              0.996931       0.916667
#      total [######............................................] 12.22%
# this epoch [#####.............................................] 10.96%
#      13700 iter, 61 epoch / 500 epochs
#     100.54 iters/sec. Estimated time to finish: 0:16:18.633254.
#      total [######............................................] 12.31%
# this epoch [###########################.......................] 55.56%
#      13800 iter, 61 epoch / 500 epochs
#     100.47 iters/sec. Estimated time to finish: 0:16:18.349063.
# 62          135.955       0.00774645  0.636238              0.99707        0.921354
#      total [######............................................] 12.40%
# this epoch [..................................................]  0.17%
#      13900 iter, 62 epoch / 500 epochs
#     100.21 iters/sec. Estimated time to finish: 0:16:19.874435.
#      total [######............................................] 12.49%
# this epoch [######################............................] 44.77%
#      14000 iter, 62 epoch / 500 epochs
#     100.11 iters/sec. Estimated time to finish: 0:16:19.897095.
#      total [######............................................] 12.58%
# this epoch [############################################......] 89.38%
#      14100 iter, 62 epoch / 500 epochs
#     99.933 iters/sec. Estimated time to finish: 0:16:20.592564.
# 63          138.337       0.0150729   0.661011              0.995536       0.915625
#      total [######............................................] 12.67%
# this epoch [################..................................] 33.98%
#      14200 iter, 63 epoch / 500 epochs
#     99.762 iters/sec. Estimated time to finish: 0:16:21.273784.
#      total [######............................................] 12.76%
# this epoch [#######################################...........] 78.59%
#      14300 iter, 63 epoch / 500 epochs
#     100.35 iters/sec. Estimated time to finish: 0:16:14.551095.
# 64          140.699       0.0205256   0.618607              0.993025       0.926562
#      total [######............................................] 12.85%
# this epoch [###########.......................................] 23.19%
#      14400 iter, 64 epoch / 500 epochs
#     100.18 iters/sec. Estimated time to finish: 0:16:15.212334.
#      total [######............................................] 12.94%
# this epoch [#################################.................] 67.80%
#      14500 iter, 64 epoch / 500 epochs
#      99.98 iters/sec. Estimated time to finish: 0:16:16.136415.
# 65          143.15        0.00997772  0.615933              0.996667       0.917188
#      total [######............................................] 13.02%
# this epoch [######............................................] 12.41%
#      14600 iter, 65 epoch / 500 epochs
#     99.759 iters/sec. Estimated time to finish: 0:16:17.292577.
#      total [######............................................] 13.11%
# this epoch [############################......................] 57.01%
#      14700 iter, 65 epoch / 500 epochs
#     99.722 iters/sec. Estimated time to finish: 0:16:16.655849.
# 66          145.505       0.0105565   0.571963              0.996791       0.925
#      total [######............................................] 13.20%
# this epoch [..................................................]  1.62%
#      14800 iter, 66 epoch / 500 epochs
#     99.471 iters/sec. Estimated time to finish: 0:16:18.109877.
#      total [######............................................] 13.29%
# this epoch [#######################...........................] 46.22%
#      14900 iter, 66 epoch / 500 epochs
#     99.429 iters/sec. Estimated time to finish: 0:16:17.516877.
#      total [######............................................] 13.38%
# this epoch [#############################################.....] 90.83%
#      15000 iter, 66 epoch / 500 epochs
#     99.268 iters/sec. Estimated time to finish: 0:16:18.100530.
# 67          147.897       0.00613132  0.572382              0.997907       0.899479
#      total [######............................................] 13.47%
# this epoch [#################.................................] 35.43%
#      15100 iter, 67 epoch / 500 epochs
#     99.081 iters/sec. Estimated time to finish: 0:16:18.934764.
#      total [######............................................] 13.56%
# this epoch [########################################..........] 80.04%
#      15200 iter, 67 epoch / 500 epochs
#     98.914 iters/sec. Estimated time to finish: 0:16:19.578799.
# 68          150.287       0.00704903  0.676424              0.997907       0.914583
#      total [######............................................] 13.65%
# this epoch [############......................................] 24.64%
#      15300 iter, 68 epoch / 500 epochs
#     98.686 iters/sec. Estimated time to finish: 0:16:20.826085.
#      total [######............................................] 13.74%
# this epoch [##################################................] 69.25%
#      15400 iter, 68 epoch / 500 epochs
#     98.518 iters/sec. Estimated time to finish: 0:16:21.482883.
# 69          153.386       0.012571    0.545844              0.994978       0.925
#      total [######............................................] 13.83%
# this epoch [######............................................] 13.86%
#      15500 iter, 69 epoch / 500 epochs
#     97.652 iters/sec. Estimated time to finish: 0:16:29.158301.
#      total [######............................................] 13.92%
# this epoch [#############################.....................] 58.46%
#      15600 iter, 69 epoch / 500 epochs
#     97.591 iters/sec. Estimated time to finish: 0:16:28.758070.
# 70          155.818       0.0160516   0.515798              0.993333       0.905729
#      total [#######...........................................] 14.01%
# this epoch [#.................................................]  3.07%
#      15700 iter, 70 epoch / 500 epochs
#     97.362 iters/sec. Estimated time to finish: 0:16:30.051605.
#      total [#######...........................................] 14.10%
# this epoch [#######################...........................] 47.67%
#      15800 iter, 70 epoch / 500 epochs
#     97.302 iters/sec. Estimated time to finish: 0:16:29.639657.
#      total [#######...........................................] 14.18%
# this epoch [##############################################....] 92.28%
#      15900 iter, 70 epoch / 500 epochs
#     97.144 iters/sec. Estimated time to finish: 0:16:30.222574.
# 71          158.224       0.0199205   0.576345              0.993443       0.907812
#      total [#######...........................................] 14.27%
# this epoch [##################................................] 36.88%
#      16000 iter, 71 epoch / 500 epochs
#     96.585 iters/sec. Estimated time to finish: 0:16:34.916696.
#      total [#######...........................................] 14.36%
# this epoch [########################################..........] 81.49%
#      16100 iter, 71 epoch / 500 epochs
#      96.34 iters/sec. Estimated time to finish: 0:16:36.409554.
# 72          161.185       0.0119891   0.653327              0.995396       0.93125
#      total [#######...........................................] 14.45%
# this epoch [#############.....................................] 26.09%
#      16200 iter, 72 epoch / 500 epochs
#     96.225 iters/sec. Estimated time to finish: 0:16:36.553297.
#      total [#######...........................................] 14.54%
# this epoch [###################################...............] 70.70%
#      16300 iter, 72 epoch / 500 epochs
#     96.103 iters/sec. Estimated time to finish: 0:16:36.780175.
# 73          163.787       0.0142642   0.657606              0.99442        0.91875
#      total [#######...........................................] 14.63%
# this epoch [#######...........................................] 15.31%
#      16400 iter, 73 epoch / 500 epochs
#     95.637 iters/sec. Estimated time to finish: 0:16:40.595658.
# ...
#     106600 iter, 475 epoch / 500 epochs
#     39.808 iters/sec. Estimated time to finish: 0:02:18.006156.
#      total [###############################################...] 95.19%
# this epoch [###############################################...] 94.09%
#     106700 iter, 475 epoch / 500 epochs
#     39.734 iters/sec. Estimated time to finish: 0:02:15.746087.
# 476         1855.58       0.00667503  0.84721               0.997349       0.923437
#      total [###############################################...] 95.28%
# this epoch [###################...............................] 38.70%
#     106800 iter, 476 epoch / 500 epochs
#     39.693 iters/sec. Estimated time to finish: 0:02:13.367990.
#      total [###############################################...] 95.37%
# this epoch [#########################################.........] 83.30%
#     106900 iter, 476 epoch / 500 epochs
#     39.668 iters/sec. Estimated time to finish: 0:02:10.930736.
# 477         1861.28       0.00319299  0.761774              0.998465       0.920313
#      total [###############################################...] 95.46%
# this epoch [#############.....................................] 27.91%
#     107000 iter, 477 epoch / 500 epochs
#      39.75 iters/sec. Estimated time to finish: 0:02:08.145643.
#      total [###############################################...] 95.55%
# this epoch [####################################..............] 72.51%
#     107100 iter, 477 epoch / 500 epochs
#     39.717 iters/sec. Estimated time to finish: 0:02:05.732296.
# 478         1867.11       0.00258765  0.753486              0.998744       0.917188
#      total [###############################################...] 95.63%
# this epoch [########..........................................] 17.12%
#     107200 iter, 478 epoch / 500 epochs
#     39.586 iters/sec. Estimated time to finish: 0:02:03.623285.
#      total [###############################################...] 95.72%
# this epoch [##############################....................] 61.72%
#     107300 iter, 478 epoch / 500 epochs
#     39.563 iters/sec. Estimated time to finish: 0:02:01.168308.
# 479         1873.41       0.00238572  0.774825              0.998884       0.91875
#      total [###############################################...] 95.81%
# this epoch [###...............................................]  6.33%
#     107400 iter, 479 epoch / 500 epochs
#     39.513 iters/sec. Estimated time to finish: 0:01:58.791236.
#      total [###############################################...] 95.90%
# this epoch [#########################.........................] 50.93%
#     107500 iter, 479 epoch / 500 epochs
#       39.5 iters/sec. Estimated time to finish: 0:01:56.298893.
#      total [###############################################...] 95.99%
# this epoch [###############################################...] 95.54%
#     107600 iter, 479 epoch / 500 epochs
#      39.49 iters/sec. Estimated time to finish: 0:01:53.793611.
# 480         1879.05       0.00242005  0.744872              0.999163       0.921875
#      total [################################################..] 96.08%
# this epoch [####################..............................] 40.14%
#     107700 iter, 480 epoch / 500 epochs
#     39.482 iters/sec. Estimated time to finish: 0:01:51.284213.
#      total [################################################..] 96.17%
# this epoch [##########################################........] 84.75%
#     107800 iter, 480 epoch / 500 epochs
#     39.551 iters/sec. Estimated time to finish: 0:01:48.561602.
# 481         1884.9        0.00285099  0.899406              0.998333       0.927604
#      total [################################################..] 96.26%
# this epoch [##############....................................] 29.36%
#     107900 iter, 481 epoch / 500 epochs
#     39.514 iters/sec. Estimated time to finish: 0:01:46.132480.
#      total [################################################..] 96.35%
# this epoch [####################################..............] 73.96%
#     108000 iter, 481 epoch / 500 epochs
#     39.485 iters/sec. Estimated time to finish: 0:01:43.677828.
# 482         1890.68       0.00963572  0.794939              0.997489       0.915104
#      total [################################################..] 96.44%
# this epoch [#########.........................................] 18.57%
#     108100 iter, 482 epoch / 500 epochs
#     39.416 iters/sec. Estimated time to finish: 0:01:41.323607.
#      total [################################################..] 96.53%
# this epoch [###############################...................] 63.17%
#     108200 iter, 482 epoch / 500 epochs
#     39.389 iters/sec. Estimated time to finish: 0:01:38.852895.
# 483         1897.29       0.00446928  0.826409              0.997768       0.919792
#      total [################################################..] 96.62%
# this epoch [###...............................................]  7.78%
#     108300 iter, 483 epoch / 500 epochs
#     39.305 iters/sec. Estimated time to finish: 0:01:36.521431.
#      total [################################################..] 96.70%
# this epoch [##########################........................] 52.38%
#     108400 iter, 483 epoch / 500 epochs
#     39.298 iters/sec. Estimated time to finish: 0:01:33.994001.
#      total [################################################..] 96.79%
# this epoch [################################################..] 96.99%
#     108500 iter, 483 epoch / 500 epochs
#     39.328 iters/sec. Estimated time to finish: 0:01:31.377979.
# 484         1902.95       0.00267143  0.856323              0.998465       0.934375
#      total [################################################..] 96.88%
# this epoch [####################..............................] 41.59%
#     108600 iter, 484 epoch / 500 epochs
#     39.236 iters/sec. Estimated time to finish: 0:01:29.043475.
#      total [################################################..] 96.97%
# this epoch [###########################################.......] 86.20%
#     108700 iter, 484 epoch / 500 epochs
#     39.202 iters/sec. Estimated time to finish: 0:01:26.571153.
# 485         1909.29       0.00270116  0.906346              0.998605       0.910417
#      total [################################################..] 97.06%
# this epoch [###############...................................] 30.81%
#     108800 iter, 485 epoch / 500 epochs
#     39.164 iters/sec. Estimated time to finish: 0:01:24.101499.
#      total [################################################..] 97.15%
# this epoch [#####################################.............] 75.41%
#     108900 iter, 485 epoch / 500 epochs
#     39.129 iters/sec. Estimated time to finish: 0:01:21.622021.
# 486         1915.1        0.00244425  0.956936              0.998889       0.913021
#      total [################################################..] 97.24%
# this epoch [##########........................................] 20.02%
#     109000 iter, 486 epoch / 500 epochs
#     39.091 iters/sec. Estimated time to finish: 0:01:19.141996.
#      total [################################################..] 97.33%
# this epoch [################################..................] 64.62%
#     109100 iter, 486 epoch / 500 epochs
#     39.042 iters/sec. Estimated time to finish: 0:01:16.680772.
# 487         1921.04       0.00281064  0.814287              0.998465       0.926562
#      total [################################################..] 97.42%
# this epoch [####..............................................]  9.23%
#     109200 iter, 487 epoch / 500 epochs
#     38.984 iters/sec. Estimated time to finish: 0:01:14.229445.
#      total [################################################..] 97.51%
# this epoch [##########################........................] 53.83%
#     109300 iter, 487 epoch / 500 epochs
#     38.936 iters/sec. Estimated time to finish: 0:01:11.752201.
#      total [################################################..] 97.60%
# this epoch [#################################################.] 98.44%
#     109400 iter, 487 epoch / 500 epochs
#     38.873 iters/sec. Estimated time to finish: 0:01:09.295460.
# 488         1927.66       0.0024856   0.752639              0.998605       0.902083
#      total [################################################..] 97.69%
# this epoch [#####################.............................] 43.04%
#     109500 iter, 488 epoch / 500 epochs
#     38.774 iters/sec. Estimated time to finish: 0:01:06.894844.
#      total [################################################..] 97.78%
# this epoch [###########################################.......] 87.65%
#     109600 iter, 488 epoch / 500 epochs
#     38.716 iters/sec. Estimated time to finish: 0:01:04.410712.
# 489         1934.11       0.00250615  0.834907              0.998884       0.921354
#      total [################################################..] 97.86%
# this epoch [################..................................] 32.26%
#     109700 iter, 489 epoch / 500 epochs
#     38.667 iters/sec. Estimated time to finish: 0:01:01.907187.
#      total [################################################..] 97.95%
# this epoch [######################################............] 76.86%
#     109800 iter, 489 epoch / 500 epochs
#      38.62 iters/sec. Estimated time to finish: 0:00:59.392811.
# 490         1940.37       0.00249406  0.775319              0.998744       0.923437
#      total [#################################################.] 98.04%
# this epoch [##########........................................] 21.47%
#     109900 iter, 490 epoch / 500 epochs
#     38.567 iters/sec. Estimated time to finish: 0:00:56.881921.
#      total [#################################################.] 98.13%
# this epoch [#################################.................] 66.07%
#     110000 iter, 490 epoch / 500 epochs
#     38.617 iters/sec. Estimated time to finish: 0:00:54.218666.
# 491         1946.51       0.0022592   0.852117              0.99875        0.93125
#      total [#################################################.] 98.22%
# this epoch [#####.............................................] 10.68%
#     110100 iter, 491 epoch / 500 epochs
#      38.56 iters/sec. Estimated time to finish: 0:00:51.704586.
#      total [#################################################.] 98.31%
# this epoch [###########################.......................] 55.28%
#     110200 iter, 491 epoch / 500 epochs
#     38.534 iters/sec. Estimated time to finish: 0:00:49.144789.
#      total [#################################################.] 98.40%
# this epoch [#################################################.] 99.89%
#     110300 iter, 491 epoch / 500 epochs
#     38.474 iters/sec. Estimated time to finish: 0:00:46.622314.
# 492         1952.95       0.00246668  0.829009              0.999023       0.929688
#      total [#################################################.] 98.49%
# this epoch [######################............................] 44.49%
#     110400 iter, 492 epoch / 500 epochs
#     38.423 iters/sec. Estimated time to finish: 0:00:44.081495.
#      total [#################################################.] 98.58%
# this epoch [############################################......] 89.10%
#     110500 iter, 492 epoch / 500 epochs
#     38.382 iters/sec. Estimated time to finish: 0:00:41.523166.
# 493         1959.04       0.00342741  0.849509              0.997907       0.925
#      total [#################################################.] 98.67%
# this epoch [################..................................] 33.71%
#     110600 iter, 493 epoch / 500 epochs
#     38.304 iters/sec. Estimated time to finish: 0:00:38.997307.
#      total [#################################################.] 98.76%
# this epoch [#######################################...........] 78.31%
#     110700 iter, 493 epoch / 500 epochs
#     38.253 iters/sec. Estimated time to finish: 0:00:36.435352.
# 494         1965.27       0.00346143  0.860009              0.998186       0.900521
#      total [#################################################.] 98.85%
# this epoch [###########.......................................] 22.92%
#     110800 iter, 494 epoch / 500 epochs
#     38.203 iters/sec. Estimated time to finish: 0:00:33.864727.
#      total [#################################################.] 98.94%
# this epoch [#################################.................] 67.52%
#     110900 iter, 494 epoch / 500 epochs
#     38.152 iters/sec. Estimated time to finish: 0:00:31.289486.
# 495         1971.62       0.00577383  0.718961              0.998465       0.918229
#      total [#################################################.] 99.02%
# this epoch [######............................................] 12.13%
#     111000 iter, 495 epoch / 500 epochs
#     38.084 iters/sec. Estimated time to finish: 0:00:28.719680.
#      total [#################################################.] 99.11%
# this epoch [############################......................] 56.73%
#     111100 iter, 495 epoch / 500 epochs
#     38.041 iters/sec. Estimated time to finish: 0:00:26.123454.
# 496         1977.77       0.00510214  0.804387              0.998186       0.921354
#      total [#################################################.] 99.20%
# this epoch [..................................................]  1.34%
#     111200 iter, 496 epoch / 500 epochs
#     37.979 iters/sec. Estimated time to finish: 0:00:23.532558.
#      total [#################################################.] 99.29%
# this epoch [######################............................] 45.94%
#     111300 iter, 496 epoch / 500 epochs
#     37.951 iters/sec. Estimated time to finish: 0:00:20.915127.
#      total [#################################################.] 99.38%
# this epoch [#############################################.....] 90.55%
#     111400 iter, 496 epoch / 500 epochs
#     37.907 iters/sec. Estimated time to finish: 0:00:18.301305.
# 497         1984.07       0.00236934  0.848198              0.99875        0.926042
#      total [#################################################.] 99.47%
# this epoch [#################.................................] 35.15%
#     111500 iter, 497 epoch / 500 epochs
#     37.861 iters/sec. Estimated time to finish: 0:00:15.682274.
#      total [#################################################.] 99.56%
# this epoch [#######################################...........] 79.76%
#     111600 iter, 497 epoch / 500 epochs
#     37.873 iters/sec. Estimated time to finish: 0:00:13.037116.
# 498         1990.19       0.00244672  0.759833              0.998605       0.932813
#      total [#################################################.] 99.65%
# this epoch [############......................................] 24.37%
#     111700 iter, 498 epoch / 500 epochs
#     37.698 iters/sec. Estimated time to finish: 0:00:10.444729.
#      total [#################################################.] 99.74%
# this epoch [##################################................] 68.97%
#     111800 iter, 498 epoch / 500 epochs
#     37.653 iters/sec. Estimated time to finish: 0:00:07.801529.
# 499         1997.17       0.00226108  0.729334              0.998884       0.907292
#      total [#################################################.] 99.83%
# this epoch [######............................................] 13.58%
#     111900 iter, 499 epoch / 500 epochs
#     37.594 iters/sec. Estimated time to finish: 0:00:05.153720.
#      total [#################################################.] 99.92%
# this epoch [#############################.....................] 58.18%
#     112000 iter, 499 epoch / 500 epochs
#     37.449 iters/sec. Estimated time to finish: 0:00:02.503423.
# 500         2004.32       0.0029427   0.842694              0.998465       0.913542
# Training done. Total time was 0:33:24.371374
